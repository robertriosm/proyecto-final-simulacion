# %%
import random


allStr = []
maxCap = []

def genLists(amount, capacity):
    for a in range(0, amount):
        allStr.append([])
        maxCap.append(random.randint(1, capacity))

# %%
# Move the cars

def simulate_system(cars):

    iterations = 0

    while cars > 0:
        iterations += 1

        # Move cars
        for i in range(len(allStr) - 1):
            current_list = allStr[i]
            next_list = allStr[i + 1]

            if len(current_list) > 0:
                car = current_list.pop(0)

                if len(next_list) < maxCap[i + 1]:
                    next_list.append(car)
                else:
                    current_list.insert(0, car)

        # Handle the last list
        last_list = allStr[-1]
        if len(last_list) > 0:
            last_car = last_list.pop(0)
            cars -= 1

        # Add 1 to a random list
        random_list_index = random.randint(0, len(allStr) - 1)
        random_list = allStr[random_list_index]

        if len(random_list) < maxCap[random_list_index]:
            random_list.append(1)

    return iterations

def simulate_systemGenAlg(cars, amount, capacity, maxCap2):

    iterations = 0
    population = 100
    mut_rate = 0.2
    best =  True
    first = True

    bestOfAll = 10000
    same = 0

    # Generate initial population
    while best:

        popList = []


        for a in range(0, population-1):
            maxCap1 = []
            for i in range(0, amount):
                maxCap1.append(random.randint(1, capacity))

            popList.append(maxCap)


        if first:
            popList.append(maxCap2)
            first = False

        else:
            while len(popList)-5<=population:
                kid = []
                for i in range(0, amount):
                    if random.random()<0.2:
                        kid.append(top5[0][i])
                    elif 0.2 < random.random() < 0.4:
                        kid.append(top5[1][i])
                    elif 0.4 < random.random() < 0.6:
                        kid.append(top5[2][i])
                    elif 0.6 < random.random() < 0.8:
                        kid.append(top5[3][i])
                    else:
                        kid.append(top5[4][i])
                # Mutate
                for a in range(0, len(kid)):
                    if random.random()< mut_rate:
                        kid[a] = random.randint(1, capacity)
                popList.append(kid)

            popList.append(top5)

        totalIt = []

        for a in range(0, len(popList)):

            while cars > 0:
                iterations += 1

                # Move cars
                for i in range(len(allStr) - 1):
                    current_list = allStr[i]
                    next_list = allStr[i + 1]

                    if len(current_list) > 0:
                        car = current_list.pop(0)

                        if len(next_list) < popList[a][i + 1]:
                            next_list.append(car)
                        else:
                            current_list.insert(0, car)

                # Handle the last list
                last_list = allStr[-1]
                if len(last_list) > 0:
                    last_car = last_list.pop(0)
                    cars -= 1

                # Add 1 to a random list
                random_list_index = random.randint(0, len(allStr) - 1)
                random_list = allStr[random_list_index]

                if len(random_list) < popList[a][random_list_index]:
                    random_list.append(1)

                totalIt.append(iterations)

        # Fitness
        # Fitness
        min_values = sorted(set(totalIt))[:5]  # Get the 5 unique lowest values
        bestIndex = [index for index, value in enumerate(totalIt) if value in min_values]

        top5 = []

        # Check the length of bestIndex before trying to access elements
        for a in range(min(5, len(bestIndex))):
            top5.append(popList[bestIndex[a]])



        if min_values[0]< bestOfAll:
            bestOfAll = min_values[0]

        else:
            same += 1

        if same == 5:
            best = False


    return top5

# %%
amnt = 10
cap=25
cars1 = random.randint(50, 100)
genLists(amnt, cap)
iterations_taken = simulate_system(cars1)
print(f"Cars took {iterations_taken} iterations to leave the system.")
genetic = simulate_systemGenAlg(cars1, amnt, cap, maxCap)
# Out:
# Cars took 54 iterations to leave the system.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-32-66f7fef45348> in <module>
#       5 iterations_taken = simulate_system(cars1)
#       6 print(f"Cars took {iterations_taken} iterations to leave the system.")
# ----> 7 genetic = simulate_systemGenAlg(cars1, amnt, cap, maxCap)
#
# <ipython-input-27-95c7954e7abf> in simulate_systemGenAlg(cars, amount, capacity, maxCap2)
#     135
#     136
# --> 137         if min_values[0]< bestOfAll:
#     138             bestOfAll = min_values[0]
#     139
#
# IndexError: list index out of range
